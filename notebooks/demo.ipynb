# %%
# !git clone https://github.com/OutsideRebelBox/AI-Contract-Clause-Identifier.git
# %cd AI-Contract-Clause-Identifier
# Out:
# Cloning into 'AI-Contract-Clause-Identifier'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 89 (delta 17), reused 2 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (89/89), 6.85 MiB | 10.69 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# /content/AI-Contract-Clause-Identifier

# %%
# !pip -q install python-docx pdfplumber pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 60.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 77.5 MB/s eta 0:00:00

# %%
# !python scripts/detect_clauses_regex.py
# Out:
# Skipping unsupported file (convert to .docx): Aegis Ratheon PBL SOW.doc
# ✅ Saved: /content/AI-Contract-Clause-Identifier/outputs/report_regex.csv
#                                          file  ...                                            snippet
# 4  Capella Master Service Agreement 2024.docx  ...  Capella Master Service Agreement\nBY (I) ACCEP...
# 0  Capella Master Service Agreement 2024.docx  ...  Capella Master Service Agreement\nBY (I) ACCEP...
# 1  Capella Master Service Agreement 2024.docx  ...  Capella Master Service Agreement\nBY (I) ACCEP...
# 3  Capella Master Service Agreement 2024.docx  ...  Capella Master Service Agreement\nBY (I) ACCEP...
# 2  Capella Master Service Agreement 2024.docx  ...  Capella Master Service Agreement\nBY (I) ACCEP...
# 5                    NDA Hifn, Inc. 2008.docx  ...  CONFIDENTIALITY AND NON-DISCLOSURE AGREEMENT\n...
# 8                    NDA Hifn, Inc. 2008.docx  ...  2.1 Non-disclosure. Both parties shall keep st...
# ...

# %%
import pandas as pd
pd.read_csv("outputs/report_regex.csv").head(20)
# Out:
#                                                  file  \
# 0          Capella Master Service Agreement 2024.docx
# 1          Capella Master Service Agreement 2024.docx
# 2          Capella Master Service Agreement 2024.docx
# 3          Capella Master Service Agreement 2024.docx
# 4          Capella Master Service Agreement 2024.docx
# 5                            NDA Hifn, Inc. 2008.docx
# 6                            NDA Hifn, Inc. 2008.docx
# 7                            NDA Hifn, Inc. 2008.docx
# 8                            NDA Hifn, Inc. 2008.docx
# 9                            NDA Hifn, Inc. 2008.docx
# 10                      New York Housing MSA 2019.pdf
# 11                      New York Housing MSA 2019.pdf
# 12                      New York Housing MSA 2019.pdf
# 13                      New York Housing MSA 2019.pdf
# 14                      New York Housing MSA 2019.pdf
# 15  NonDisclosure Agreement Hifn, Inc. v Exar Corp...
# ...

# %%
from google.colab import files
files.download("outputs/report_regex.csv")
